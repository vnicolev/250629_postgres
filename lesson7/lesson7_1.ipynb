# %% [markdown]
# ## Python 基本資料型別

# %%
print("Hello! Python!")
15 #整數(int)
15.0 #浮點數(float)
"15.0" #字串(str)
'15.0' #字串(str)
True #布林值(bool)
False #布林值(bool)
None #空值(NoneType)
# Out:
# Hello! Python!
